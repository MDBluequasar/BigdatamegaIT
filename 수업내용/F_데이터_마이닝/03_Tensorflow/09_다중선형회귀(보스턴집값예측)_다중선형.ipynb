# %% [markdown]
# # 제목
#
# ## #01. 패키지 준비하기

# %%
import sys
sys.path.append('../../')
import helper

from pandas import read_excel, DataFrame, merge
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## #02. 데이터셋 준비하기

# %%
origin = read_excel("https://data.hossam.kr/E04/boston.xlsx")
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   INDUS      506 non-null    float64
#  3   CHAS       506 non-null    int64
#  4   NOX        506 non-null    float64
#  5   RM         506 non-null    float64
#  6   AGE        506 non-null    float64
#  7   DIS        506 non-null    float64
#  8   RAD        506 non-null    int64
#  9   TAX        506 non-null    int64
#  10  PTRATIO    506 non-null    float64
#  11  B          506 non-null    float64
#  12  LSTAT      506 non-null    float64
#  13  MEDV       506 non-null    float64
#  14  CAT. MEDV  506 non-null    int64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### 결측치 확인

# %%
origin.isna().sum()
# Out:
# CRIM         0
# ZN           0
# INDUS        0
# CHAS         0
# NOX          0
# RM           0
# AGE          0
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT        0
# MEDV         0
# CAT. MEDV    0
# dtype: int64

# %% [markdown]
# ## #04. 탐색적 데이터 분석
#
# ### 명목형 처리

# %%
origin['CHAS'] = origin['CHAS'].astype('category')
origin['CAT. MEDV'] = origin['CAT. MEDV'].astype('category')
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   INDUS      506 non-null    float64
#  3   CHAS       506 non-null    category
#  4   NOX        506 non-null    float64
#  5   RM         506 non-null    float64
#  6   AGE        506 non-null    float64
#  7   DIS        506 non-null    float64
#  8   RAD        506 non-null    int64
#  9   TAX        506 non-null    int64
#  10  PTRATIO    506 non-null    float64
#  11  B          506 non-null    float64
#  12  LSTAT      506 non-null    float64
#  13  MEDV       506 non-null    float64
#  14  CAT. MEDV  506 non-null    category
# dtypes: category(2), float64(11), int64(2)
# memory usage: 52.7 KB

# %% [markdown]
# 기본통계 확인

# %%
origin.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         RAD         TAX     PTRATIO           B       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.653063
# std      2.105710    8.707259  168.537116    2.164946   91.294864    7.141062
# min      1.129600    1.000000  187.000000   12.600000    0.320000    1.730000
# 25%      2.100175    4.000000  279.000000   17.400000  375.377500    6.950000
# 50%      3.207450    5.000000  330.000000   19.050000  391.440000   11.360000
# 75%      5.188425   24.000000  666.000000   20.200000  396.225000   16.955000
# max     12.126500   24.000000  711.000000   22.000000  396.900000   37.970000
#
#              MEDV
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %% [markdown]
# ### 상자그림

# %%
plt.figure(figsize=(10, 5))
sb.boxplot(data=origin)
plt.show()
plt.close()

# %% [markdown]
# 산점도 그래프와 추세선 확인

# %%
# plt.figure(figsize=(30, 30))
# sb.pairplot(origin)
# plt.show()
# plt.close()

# %% [markdown]
# 상관계수 확인

# %%
corr = origin.drop('MEDV', axis = 1).corr()
corr
# Out:
#                CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM       1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN        -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS      0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS      -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX        0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM        -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE        0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS       -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD        0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX        0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO    0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B         -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# LSTAT      0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808
# CAT. MEDV -0.151987  0.365296 -0.366276  0.108631 -0.232502  0.641265
#
#                 AGE       DIS       RAD       TAX   PTRATIO         B  \
# CRIM       0.352734 -0.379670  0.625505  0.582764  0.289946 -0.385064
# ZN        -0.569537  0.664408 -0.311948 -0.314563 -0.391679  0.175520
# INDUS      0.644779 -0.708027  0.595129  0.720760  0.383248 -0.356977
# CHAS       0.086518 -0.099176 -0.007368 -0.035587 -0.121515  0.048788
# NOX        0.731470 -0.769230  0.611441  0.668023  0.188933 -0.380051
# RM        -0.240265  0.205246 -0.209847 -0.292048 -0.355501  0.128069
# AGE        1.000000 -0.747881  0.456022  0.506456  0.261515 -0.273534
# DIS       -0.747881  1.000000 -0.494588 -0.534432 -0.232471  0.291512
# RAD        0.456022 -0.494588  1.000000  0.910228  0.464741 -0.444413
# TAX        0.506456 -0.534432  0.910228  1.000000  0.460853 -0.441808
# PTRATIO    0.261515 -0.232471  0.464741  0.460853  1.000000 -0.177383
# B         -0.273534  0.291512 -0.444413 -0.441808 -0.177383  1.000000
# LSTAT      0.602339 -0.496996  0.488676  0.543993  0.374044 -0.366087
# CAT. MEDV -0.191196  0.118887 -0.197924 -0.273687 -0.443425  0.155137
#
#               LSTAT  CAT. MEDV
# CRIM       0.455621  -0.151987
# ZN        -0.412995   0.365296
# INDUS      0.603800  -0.366276
# CHAS      -0.053929   0.108631
# NOX        0.590879  -0.232502
# RM        -0.613808   0.641265
# AGE        0.602339  -0.191196
# DIS       -0.496996   0.118887
# RAD        0.488676  -0.197924
# TAX        0.543993  -0.273687
# PTRATIO    0.374044  -0.443425
# B         -0.366087   0.155137
# LSTAT      1.000000  -0.469911
# CAT. MEDV -0.469911   1.000000

# %% [markdown]
# 상관계수 히트맵

# %%
plt.figure(figsize = (15, 10))
sb.heatmap(corr, annot = True, cmap = 'Greens', vmin = -1, vmax = 1, linewidths = .5)
plt.show()
plt.close()

# %% [markdown]
# 제외하기로 한 독립변수 제거
#
#   > 상관게수의 절대값이 `0.7` 이상인 항목을 순차적으로 제거하여 회귀분석에 사용할 요인을 선정

# %%
x = origin.drop(['TAX','DIS','NOX','INDUS'], axis = 1)
x
# Out:
#         CRIM    ZN CHAS     RM   AGE  RAD  PTRATIO       B  LSTAT  MEDV  \
# 0    0.00632  18.0    0  6.575  65.2    1     15.3  396.90   4.98  24.0
# 1    0.02731   0.0    0  6.421  78.9    2     17.8  396.90   9.14  21.6
# 2    0.02729   0.0    0  7.185  61.1    2     17.8  392.83   4.03  34.7
# 3    0.03237   0.0    0  6.998  45.8    3     18.7  394.63   2.94  33.4
# 4    0.06905   0.0    0  7.147  54.2    3     18.7  396.90   5.33  36.2
# ..       ...   ...  ...    ...   ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0    0  6.593  69.1    1     21.0  391.99   9.67  22.4
# 502  0.04527   0.0    0  6.120  76.7    1     21.0  396.90   9.08  20.6
# 503  0.06076   0.0    0  6.976  91.0    1     21.0  396.90   5.64  23.9
# 504  0.10959   0.0    0  6.794  89.3    1     21.0  393.45   6.48  22.0
# 505  0.04741   0.0    0  6.030  80.8    1     21.0  396.90   7.88  11.9
#
#     CAT. MEDV
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# ..        ...
# 501         0
# 502         0
# 503         0
# 504         0
# 505         0
#
# [506 rows x 11 columns]

# %%
plt.figure(figsize=(15, 10))
sb.heatmap(x.corr(), annot = True, cmap = 'Greens', vmin = -1, vmax=1, linewidths=.5)
plt.show()
plt.close()

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   CHAS       506 non-null    category
#  3   RM         506 non-null    float64
#  4   AGE        506 non-null    float64
#  5   RAD        506 non-null    int64
#  6   PTRATIO    506 non-null    float64
#  7   B          506 non-null    float64
#  8   LSTAT      506 non-null    float64
#  9   MEDV       506 non-null    float64
#  10  CAT. MEDV  506 non-null    category
# dtypes: category(2), float64(8), int64(1)
# memory usage: 36.9 KB

# %% [markdown]
# 명목형 변수만 추출

# %%
categorical_df = x.filter(['CHAS', 'CAT.MEDV'])
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CHAS    506 non-null    category
# dtypes: category(1)
# memory usage: 758.0 bytes

# %% [markdown]
# 종속변수만 추출

# %%
y = x['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# 데이터 프레임에서 추출한 필드를 제거

# %%
x.drop(['CHAS', 'CAT. MEDV', 'MEDV'], axis = 1, inplace = True)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   RM       506 non-null    float64
#  3   AGE      506 non-null    float64
#  4   RAD      506 non-null    int64
#  5   PTRATIO  506 non-null    float64
#  6   B        506 non-null    float64
#  7   LSTAT    506 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 31.8 KB

# %% [markdown]
# 최종 산점도 행렬 확인

# %%
plt.figure(figsize=(30, 30))
sb.pairplot(x)
plt.show()
plt.savefig("pairplot.png")
plt.close()
# Out:
# d:\python\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## #05. 데이터셋 분할하기
#
# ### 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# ### 데이터 표준화

# %%
x_scaller = StandardScaler()
x_scale = x_scaller.fit_transform(x)
x_scale
# Out:
# array([[-0.41978194,  0.28482986,  0.41367189, ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236,  0.19427445, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236,  1.28271368, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.98496002, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.72567214, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236, -0.36276709, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %% [markdown]
# 분리해 놓은 명목형 데이터와 결합
#
#   1. 명목형 변수의 값이 `0`, `1` 두 종류 밖에 없기 때문에 별도로 더미변수 처리는 필요 없다.
#
#   2. 표준화의 결과와 병합이 필요하지만 표준화 함수는 리턴 타입이 numpyy array이므로 이를 다시 DataFrame으로 변환해야만 명목형과 결합이 가능하다.

# %%
x_scale_df = DataFrame(x_scale, columns = x.columns)
x_scale_df
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 0   -0.419782  0.284830  0.413672 -0.120013 -0.982843 -1.459000  0.441052
# 1   -0.417339 -0.487722  0.194274  0.367166 -0.867883 -0.303094  0.441052
# 2   -0.417342 -0.487722  1.282714 -0.265812 -0.867883 -0.303094  0.396427
# 3   -0.416750 -0.487722  1.016303 -0.809889 -0.752922  0.113032  0.416163
# 4   -0.412482 -0.487722  1.228577 -0.511180 -0.752922  0.113032  0.441052
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.439316  0.018673 -0.982843  1.176466  0.387217
# 502 -0.415249 -0.487722 -0.234548  0.288933 -0.982843  1.176466  0.441052
# 503 -0.413447 -0.487722  0.984960  0.797449 -0.982843  1.176466  0.441052
# 504 -0.407764 -0.487722  0.725672  0.736996 -0.982843  1.176466  0.403225
# 505 -0.415000 -0.487722 -0.362767  0.434732 -0.982843  1.176466  0.441052
#
#         LSTAT
# 0   -1.075562
# 1   -0.492439
# 2   -1.208727
# 3   -1.361517
# 4   -1.026501
# ..        ...
# 501 -0.418147
# 502 -0.500850
# 503 -0.983048
# 504 -0.865302
# 505 -0.669058
#
# [506 rows x 8 columns]

# %%
x_df = merge(x_scale_df, categorical_df, left_index=True, right_index=True)
x_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   RM       506 non-null    float64
#  3   AGE      506 non-null    float64
#  4   RAD      506 non-null    float64
#  5   PTRATIO  506 non-null    float64
#  6   B        506 non-null    float64
#  7   LSTAT    506 non-null    float64
#  8   CHAS     506 non-null    category
# dtypes: category(1), float64(8)
# memory usage: 32.4 KB

# %% [markdown]
# ### 훈련 데이터와 검증 데이터로 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y, test_size=0.3, random_state=777)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 9), (152, 9), (354,), (152,))

# %% [markdown]
# ## #06. 모델 개발
#
# ### 모델 정의

# %%
model = Sequential()

# 1차원의 데이터를 입력으로 받고, 64개의 출력을 가지는 첫 번째 Dense 층
model.add(Dense(64, activation = 'relu', input_shape = (len(x_train.columns), )))
model.add(Dense(32, activation = 'relu'))

# 하나의 값을 출력 정답의 범위가 정해지지 않기 때문에 활성화 함수는 linear
model.add(Dense(1, activation = 'linear'))

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2753 (10.75 KB)
# Trainable params: 2753 (10.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 학습하기

# %%
result = model.fit(x_train, y_train, epochs=500, validation_data=(x_test, y_test), callbacks=[
    EarlyStopping(monitor='val_loss', patience=10, verbose=1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.001, verbose=1)
])
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 28ms/step - loss: 574.5144 - mae: 22.1836 - val_loss: 541.3080 - val_mae: 21.4406 - lr: 0.0010
# Epoch 2/500
# 12/12 [==============================] - 0s 3ms/step - loss: 538.3536 - mae: 21.4175 - val_loss: 504.4688 - val_mae: 20.6207 - lr: 0.0010
# Epoch 3/500
# 12/12 [==============================] - 0s 3ms/step - loss: 497.9896 - mae: 20.5246 - val_loss: 460.9244 - val_mae: 19.6120 - lr: 0.0010
# Epoch 4/500
# 12/12 [==============================] - 0s 3ms/step - loss: 449.1348 - mae: 19.4020 - val_loss: 408.2489 - val_mae: 18.3176 - lr: 0.0010
# Epoch 5/500
# 12/12 [==============================] - 0s 3ms/step - loss: 389.9125 - mae: 17.9564 - val_loss: 344.3116 - val_mae: 16.6577 - lr: 0.0010
# Epoch 6/500
# 12/12 [==============================] - 0s 3ms/step - loss: 319.9703 - mae: 16.1500 - val_loss: 272.6769 - val_mae: 14.6143 - lr: 0.0010
# Epoch 7/500
# 12/12 [==============================] - 0s 3ms/step - loss: 243.8315 - mae: 13.9211 - val_loss: 199.6768 - val_mae: 12.2133 - lr: 0.0010
# Epoch 8/500
# 12/12 [==============================] - 0s 3ms/step - loss: 173.6836 - mae: 11.3859 - val_loss: 133.3018 - val_mae: 9.5811 - lr: 0.0010
# Epoch 9/500
# 12/12 [==============================] - 0s 3ms/step - loss: 112.6656 - mae: 8.7937 - val_loss: 83.1205 - val_mae: 7.2205 - lr: 0.0010
# Epoch 10/500
# 12/12 [==============================] - 0s 3ms/step - loss: 73.7256 - mae: 6.7970 - val_loss: 56.0045 - val_mae: 5.5713 - lr: 0.0010
# Epoch 11/500
# 12/12 [==============================] - 0s 3ms/step - loss: 53.3984 - mae: 5.6093 - val_loss: 43.9209 - val_mae: 4.6741 - lr: 0.0010
# Epoch 12/500
# 12/12 [==============================] - 0s 3ms/step - loss: 43.0209 - mae: 4.8828 - val_loss: 36.9964 - val_mae: 4.1312 - lr: 0.0010
# Epoch 13/500
# 12/12 [==============================] - 0s 3ms/step - loss: 36.3934 - mae: 4.3863 - val_loss: 32.5702 - val_mae: 3.8485 - lr: 0.0010
# Epoch 14/500
# 12/12 [==============================] - 0s 3ms/step - loss: 32.0100 - mae: 4.0210 - val_loss: 28.9816 - val_mae: 3.5905 - lr: 0.0010
# Epoch 15/500
# 12/12 [==============================] - 0s 3ms/step - loss: 28.5579 - mae: 3.7652 - val_loss: 27.0386 - val_mae: 3.4914 - lr: 0.0010
# Epoch 16/500
# 12/12 [==============================] - 0s 3ms/step - loss: 26.4348 - mae: 3.6338 - val_loss: 25.1129 - val_mae: 3.4725 - lr: 0.0010
# Epoch 17/500
# 12/12 [==============================] - 0s 3ms/step - loss: 24.7990 - mae: 3.5415 - val_loss: 24.2225 - val_mae: 3.4289 - lr: 0.0010
# Epoch 18/500
# 12/12 [==============================] - 0s 5ms/step - loss: 23.5406 - mae: 3.4287 - val_loss: 23.7349 - val_mae: 3.3815 - lr: 0.0010
# Epoch 19/500
# 12/12 [==============================] - 0s 3ms/step - loss: 22.6553 - mae: 3.3322 - val_loss: 23.4678 - val_mae: 3.3540 - lr: 0.0010
# Epoch 20/500
# 12/12 [==============================] - 0s 3ms/step - loss: 21.9811 - mae: 3.2712 - val_loss: 23.0650 - val_mae: 3.3249 - lr: 0.0010
# Epoch 21/500
# 12/12 [==============================] - 0s 3ms/step - loss: 21.3828 - mae: 3.2130 - val_loss: 22.7528 - val_mae: 3.2970 - lr: 0.0010
# Epoch 22/500
# 12/12 [==============================] - 0s 3ms/step - loss: 20.9125 - mae: 3.1746 - val_loss: 22.4345 - val_mae: 3.2777 - lr: 0.0010
# Epoch 23/500
# 12/12 [==============================] - 0s 3ms/step - loss: 20.5733 - mae: 3.1530 - val_loss: 22.1964 - val_mae: 3.2659 - lr: 0.0010
# Epoch 24/500
# 12/12 [==============================] - 0s 3ms/step - loss: 20.3460 - mae: 3.1321 - val_loss: 21.9559 - val_mae: 3.2739 - lr: 0.0010
# Epoch 25/500
# 12/12 [==============================] - 0s 4ms/step - loss: 19.9918 - mae: 3.1163 - val_loss: 21.6744 - val_mae: 3.2482 - lr: 0.0010
# Epoch 26/500
# 12/12 [==============================] - 0s 4ms/step - loss: 19.6147 - mae: 3.0739 - val_loss: 21.5330 - val_mae: 3.2356 - lr: 0.0010
# Epoch 27/500
# 12/12 [==============================] - 0s 3ms/step - loss: 19.3829 - mae: 3.0398 - val_loss: 21.6695 - val_mae: 3.2328 - lr: 0.0010
# Epoch 28/500
# 12/12 [==============================] - 0s 3ms/step - loss: 19.2876 - mae: 3.0291 - val_loss: 21.2613 - val_mae: 3.2372 - lr: 0.0010
# Epoch 29/500
# 12/12 [==============================] - 0s 3ms/step - loss: 18.8893 - mae: 3.0160 - val_loss: 21.1185 - val_mae: 3.2221 - lr: 0.0010
# Epoch 30/500
# 12/12 [==============================] - 0s 3ms/step - loss: 18.6597 - mae: 2.9927 - val_loss: 20.9187 - val_mae: 3.2038 - lr: 0.0010
# Epoch 31/500
# 12/12 [==============================] - 0s 3ms/step - loss: 18.4847 - mae: 2.9748 - val_loss: 20.7783 - val_mae: 3.1921 - lr: 0.0010
# Epoch 32/500
# 12/12 [==============================] - 0s 3ms/step - loss: 18.4236 - mae: 2.9676 - val_loss: 20.8414 - val_mae: 3.2251 - lr: 0.0010
# Epoch 33/500
# 12/12 [==============================] - 0s 3ms/step - loss: 18.2345 - mae: 2.9534 - val_loss: 20.5875 - val_mae: 3.1926 - lr: 0.0010
# Epoch 34/500
# 12/12 [==============================] - 0s 3ms/step - loss: 17.9903 - mae: 2.9507 - val_loss: 20.3852 - val_mae: 3.1676 - lr: 0.0010
# Epoch 35/500
# 12/12 [==============================] - 0s 3ms/step - loss: 17.7907 - mae: 2.9371 - val_loss: 20.2690 - val_mae: 3.1512 - lr: 0.0010
# Epoch 36/500
# 12/12 [==============================] - 0s 3ms/step - loss: 17.6658 - mae: 2.9351 - val_loss: 20.4057 - val_mae: 3.1618 - lr: 0.0010
# Epoch 37/500
# 12/12 [==============================] - 0s 3ms/step - loss: 17.6516 - mae: 2.9381 - val_loss: 20.2501 - val_mae: 3.1579 - lr: 0.0010
# Epoch 38/500
# 12/12 [==============================] - 0s 3ms/step - loss: 17.4045 - mae: 2.9041 - val_loss: 19.9306 - val_mae: 3.1417 - lr: 0.0010
# Epoch 39/500
# 12/12 [==============================] - 0s 3ms/step - loss: 17.2325 - mae: 2.9004 - val_loss: 19.8131 - val_mae: 3.1333 - lr: 0.0010
# Epoch 40/500
# 12/12 [==============================] - 0s 4ms/step - loss: 17.0674 - mae: 2.8872 - val_loss: 19.6893 - val_mae: 3.1103 - lr: 0.0010
# Epoch 41/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.9009 - mae: 2.8560 - val_loss: 19.8266 - val_mae: 3.0925 - lr: 0.0010
# Epoch 42/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.9040 - mae: 2.8334 - val_loss: 19.8633 - val_mae: 3.0868 - lr: 0.0010
# Epoch 43/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.6809 - mae: 2.8141 - val_loss: 19.3571 - val_mae: 3.0732 - lr: 0.0010
# Epoch 44/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.6515 - mae: 2.8442 - val_loss: 19.0654 - val_mae: 3.0564 - lr: 0.0010
# Epoch 45/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.5300 - mae: 2.8299 - val_loss: 19.0034 - val_mae: 3.0458 - lr: 0.0010
# Epoch 46/500
# 12/12 [==============================] - 0s 3ms/step - loss: 16.3478 - mae: 2.8076 - val_loss: 18.9356 - val_mae: 3.0459 - lr: 0.0010
# Epoch 47/500
# 12/12 [==============================] - 0s 3ms/step - loss: 16.1915 - mae: 2.7925 - val_loss: 19.0234 - val_mae: 3.0407 - lr: 0.0010
# Epoch 48/500
# 12/12 [==============================] - 0s 3ms/step - loss: 16.1805 - mae: 2.8011 - val_loss: 18.8533 - val_mae: 3.0395 - lr: 0.0010
# Epoch 49/500
# 12/12 [==============================] - 0s 3ms/step - loss: 16.1178 - mae: 2.7958 - val_loss: 18.9099 - val_mae: 3.0218 - lr: 0.0010
# Epoch 50/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.0412 - mae: 2.7841 - val_loss: 18.8381 - val_mae: 3.0193 - lr: 0.0010
# Epoch 51/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.9019 - mae: 2.7659 - val_loss: 18.7396 - val_mae: 3.0141 - lr: 0.0010
# Epoch 52/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.6504 - mae: 2.7454 - val_loss: 18.5517 - val_mae: 3.0234 - lr: 0.0010
# Epoch 53/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.5981 - mae: 2.7480 - val_loss: 18.4061 - val_mae: 2.9960 - lr: 0.0010
# Epoch 54/500
# 12/12 [==============================] - 0s 3ms/step - loss: 15.4394 - mae: 2.7234 - val_loss: 18.4990 - val_mae: 2.9831 - lr: 0.0010
# Epoch 55/500
# 12/12 [==============================] - 0s 3ms/step - loss: 15.4188 - mae: 2.6972 - val_loss: 18.4494 - val_mae: 2.9763 - lr: 0.0010
# Epoch 56/500
# 12/12 [==============================] - 0s 3ms/step - loss: 15.3016 - mae: 2.6917 - val_loss: 18.3388 - val_mae: 2.9761 - lr: 0.0010
# Epoch 57/500
# 12/12 [==============================] - 0s 5ms/step - loss: 15.1543 - mae: 2.6905 - val_loss: 18.1814 - val_mae: 2.9752 - lr: 0.0010
# Epoch 58/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.1593 - mae: 2.7076 - val_loss: 18.1190 - val_mae: 2.9763 - lr: 0.0010
# Epoch 59/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.0285 - mae: 2.6943 - val_loss: 18.0760 - val_mae: 2.9803 - lr: 0.0010
# Epoch 60/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.9535 - mae: 2.6762 - val_loss: 18.0810 - val_mae: 2.9852 - lr: 0.0010
# Epoch 61/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.7929 - mae: 2.6468 - val_loss: 18.0571 - val_mae: 2.9637 - lr: 0.0010
# Epoch 62/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.6717 - mae: 2.6383 - val_loss: 17.9789 - val_mae: 2.9631 - lr: 0.0010
# Epoch 63/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.6024 - mae: 2.6343 - val_loss: 17.9419 - val_mae: 2.9688 - lr: 0.0010
# Epoch 64/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.4492 - mae: 2.6035 - val_loss: 17.8817 - val_mae: 2.9369 - lr: 0.0010
# Epoch 65/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.4042 - mae: 2.5968 - val_loss: 17.8788 - val_mae: 2.9508 - lr: 0.0010
# Epoch 66/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.3364 - mae: 2.5963 - val_loss: 17.7551 - val_mae: 2.9403 - lr: 0.0010
# Epoch 67/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.2501 - mae: 2.5956 - val_loss: 17.7579 - val_mae: 2.9477 - lr: 0.0010
# Epoch 68/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.1763 - mae: 2.6005 - val_loss: 17.6292 - val_mae: 2.9798 - lr: 0.0010
# Epoch 69/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.0588 - mae: 2.5859 - val_loss: 17.6515 - val_mae: 2.9506 - lr: 0.0010
# Epoch 70/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.9604 - mae: 2.5741 - val_loss: 17.6426 - val_mae: 2.9816 - lr: 0.0010
# Epoch 71/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.0069 - mae: 2.5855 - val_loss: 17.5814 - val_mae: 3.0157 - lr: 0.0010
# Epoch 72/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.2946 - mae: 2.7169 - val_loss: 17.3863 - val_mae: 3.0982 - lr: 0.0010
# Epoch 73/500
# 12/12 [==============================] - 0s 3ms/step - loss: 14.3161 - mae: 2.7303 - val_loss: 16.9025 - val_mae: 2.9562 - lr: 0.0010
# Epoch 74/500
# 12/12 [==============================] - 0s 3ms/step - loss: 13.7811 - mae: 2.6032 - val_loss: 17.1609 - val_mae: 2.9656 - lr: 0.0010
# Epoch 75/500
# 12/12 [==============================] - 0s 3ms/step - loss: 13.6437 - mae: 2.5710 - val_loss: 17.0491 - val_mae: 2.9501 - lr: 0.0010
# Epoch 76/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.5943 - mae: 2.5569 - val_loss: 17.0640 - val_mae: 2.9186 - lr: 0.0010
# Epoch 77/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.4390 - mae: 2.5271 - val_loss: 17.1084 - val_mae: 2.9324 - lr: 0.0010
# Epoch 78/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.3129 - mae: 2.5055 - val_loss: 17.3046 - val_mae: 2.9871 - lr: 0.0010
# Epoch 79/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.4243 - mae: 2.5031 - val_loss: 17.4296 - val_mae: 2.9986 - lr: 0.0010
# Epoch 80/500
# 12/12 [==============================] - 0s 3ms/step - loss: 13.2403 - mae: 2.4841 - val_loss: 17.2489 - val_mae: 2.9496 - lr: 0.0010
# Epoch 81/500
# 12/12 [==============================] - 0s 3ms/step - loss: 13.1425 - mae: 2.4722 - val_loss: 17.5893 - val_mae: 2.9877 - lr: 0.0010
# Epoch 82/500
# 12/12 [==============================] - 0s 3ms/step - loss: 13.0339 - mae: 2.4740 - val_loss: 17.5057 - val_mae: 3.0111 - lr: 0.0010
# Epoch 83/500
# 12/12 [==============================] - 0s 3ms/step - loss: 13.0810 - mae: 2.4949 - val_loss: 17.4355 - val_mae: 2.9808 - lr: 0.0010
# Epoch 83: early stopping

# %% [markdown]
# ## #07. 학습 결과 평가

# %%
helper.tf_result_plot(result)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 절대오차: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 절대오차: %f" % (evaluate2[0], evaluate2[1]))
# Out:
# 12/12 [==============================] - 0s 997us/step - loss: 12.9066 - mae: 2.4716
# 최종 훈련 손실률: 12.906614, 최종 훈련 절대오차: 2.471645
# 5/5 [==============================] - 0s 2ms/step - loss: 17.4355 - mae: 2.9808
# 최종 검증 손실률: 17.435486, 최종 검증 절대오차: 2.980784

# %% [markdown]
# ## #08. 학습 결과 적용

# %% [markdown]
# ### 테스트 데이터에 대한 예측 결과 산정

# %%
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)
# Out:
# 12/12 [==============================] - 0s 907us/step
# 5/5 [==============================] - 0s 1ms/step

# %% [markdown]
# ### 결과 데이터 셋 구성

# %%
train_df = DataFrame(x_train, columns=x_train.columns)
train_df['관측치'] = y_train.values
train_df['예측치'] = train_pred.flatten()

train_df['훈련오차'] = train_df['관측치']-train_df['예측치']

train_df.head()
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 372  0.541569 -0.487722 -0.583589  0.747665  1.661245  0.806576 -0.096421
# 18  -0.327103 -0.487722 -1.180521 -1.137046 -0.637962  1.176466 -0.742112
# 185 -0.413480 -0.487722 -0.187534  0.008005 -0.752922 -0.303094  0.333711
# 57  -0.418851  3.804234  0.757015 -0.998360 -0.523001 -1.551473  0.397194
# 261 -0.358360  0.370669  1.759974  0.740552 -0.523001 -2.522434  0.347526
#
#         LSTAT CHAS   관측치        예측치       훈련오차
# 372 -0.528885    1  50.0  28.608522  21.391478
# 18  -0.134996    0  20.2  17.022425   3.177575
# 185  0.069658    0  29.6  20.438541   9.161459
# 57  -1.219941    0  31.6  32.510906  -0.910906
# 261 -0.755966    0  43.1  40.187199   2.912801

# %%
test_df = DataFrame(x_test, columns=x_train.columns)
test_df['관측치'] = y_test.values
test_df['예측치'] = test_pred.flatten()

test_df['훈련오차'] = test_df['관측치']-test_df['예측치']

test_df.head()
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 207 -0.391193 -0.487722 -0.714658  0.146691 -0.637962  0.066796  0.359148
# 425  1.425197 -0.487722 -0.553671  0.953916  1.661245  0.806576 -3.826496
# 408  0.441097 -0.487722 -0.951151  1.042817  1.661245  0.806576 -0.460876
# 63  -0.405796  0.585267  0.680083 -0.895234 -0.178120  0.575395  0.426579
# 290 -0.416442  2.945843  0.821124 -1.446423 -0.637962  0.344213  0.441052
#
#         LSTAT CHAS   관측치        예측치      훈련오차
# 207  0.757911    0  22.5  17.148722  5.351278
# 425  1.645211    0   8.3  12.222202 -3.922202
# 408  1.926960    0  17.2  11.190275  6.009725
# 63  -0.441977    0  25.0  22.200411  2.799589
# 290 -1.306849    0  28.5  30.258385 -1.758385

# %% [markdown]
# ### 실제 결과값과 머신러닝에 의한 예측값 비교

# %%
for key in ['CRIM','ZN','RM','AGE','RAD','PTRATIO','B','LSTAT']:
    helper.regplot(train_df[key], train_df['관측치'], train_df['예측치'], "훈련데이터",
                   test_df[key], test_df['관측치'], test_df['예측치'], "검증데이터",
                   figsize=(15, 5))
