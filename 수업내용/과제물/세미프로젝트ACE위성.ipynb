# %%
import json
import requests
import datetime as dt
from bs4 import BeautifulSoup
from pandas import DataFrame

# %%
url = "http://spaceweather.rra.go.kr/api/ace/sw"

# %%
# 접속 객체 생성
session  = requests.Session()

# 접속 정보 설정
session.headers.update({
    #직전에 머물렀던 페이지의 URL
    "Referer":"",
    # 브라우저 및 OS 버전 정보
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
})

# %%
# 특정 웹 페이지에 접속
r = session.get(url)
if r.status_code != 200:
    # 에러코드와 에러메시지 출력
    msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
    # 에러를 강제로 생성시킴
    raise Exception(msg)

# %%
# Out:
# <class 'str'>
# {"error":false,"errorCode":"NOERR","lastUpdate":"202306280257","data":[{"time":"202306280257","protonDensity":2.5,"bulkSpeed":457.4,"ionTemp":119300.0},{"time":"202306280256","protonDensity":2.6,"bulkSpeed":444.1,"ionTemp":165800.0},{"time":"202306280255","protonDensity":2.1,"bulkSpeed":436.9,"ionTemp":133300.0},{"time":"202306280254","protonDensity":1.8,"bulkSpeed":434.1,"ionTemp":123400.0},{"time":"202306280253","protonDensity":2.2,"bulkSpeed":440.9,"ionTemp":101700.0},{"time":"202306280252","protonDensity":2.4,"bulkSpeed":442.4,"ionTemp":87800.0},{"time":"202306280251","protonDensity":2.0,"bulkSpeed":441.5,"ionTemp":103700.0},{"time":"202306280250","protonDensity":2.3,"bulkSpeed":439.1,"ionTemp":108900.0},{"time":"202306280249","protonDensity":2.4,"bulkSpeed":441.6,"ionTemp":97500.0},{"time":"202306280248","protonDensity":2.3,"bulkSpeed":440.5,"ionTemp":108200.0},{"time":"202306280247","protonDensity":2.3,"bulkSpeed":440.5,"ionTemp":95800.0},{"time":"202306280246","protonDensity":2.3,"bulkSpeed":443.6,"ionTemp":87400.0},{"time":"202306280245","protonDensity":2.3,"bulkSpeed":444.8,"ionTemp":85600.0},{"time":"202306280244","protonDensity":2.6,"bulkSpeed":448.5,"ionTemp":91100.0},{"time":"202306280243","protonDensity":2.6,"bulkSpeed":448.0,"ionTemp":88900.0},{"time":"202306280242","protonDensity":2.5,"bulkSpeed":448.0,"ionTemp":86500.0},{"time":"202306280241","protonDensity":2.5,"bulkSpeed":446.2,"ionTemp":89300.0},{"time":"202306280240","protonDensity":2.7,"bulkSpeed":443.3,"ionTemp":92300.0},{"time":"202306280239","protonDensity":2.8,"bulkSpeed":445.8,"ionTemp":90500.0},{"time":"202306280238","protonDensity":2.7,"bulkSpeed":445.7,"ionTemp":97200.0},{"time":"202306280237","protonDensity":2.8,"bulkSpeed":446.3,"ionTemp":88600.0},{"time":"202306280