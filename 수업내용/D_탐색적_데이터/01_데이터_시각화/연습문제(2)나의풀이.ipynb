# %%
from matplotlib import pyplot as plt
from pandas import read_excel
import seaborn as sb
import numpy as np

# %%
plt.rcParams["font.family"] = 'Malgun Gothic'
#plt.rcParams["font.family"] = 'AppleGothic'
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (20, 5)
plt.rcParams["axes.unicode_minus"] = False

# %%
# 데이터 준비
df = read_excel("C:\\Users\\User\\Desktop\\궁둥박사\\BigdatamegaIT\\수업내용\\D_탐색적_데이터\\01_데이터_시각화/covid19.xlsx", index_col = '서울시 기준일')
df
# Out:
#              서울 확진자  서울시 일일 확진  서울시 사망       전국 확진  전국 일일 확진  전국 사망
# 서울시 기준일
# 2023-05-31  6204277     5987.0    6492  31703511.0   24411.0  34784
# 2023-05-30  6198290     3326.0    6486  31679100.0   13529.0  34767
# 2023-05-29  6194964     1393.0    6485  31665571.0    6868.0  34760
# 2023-05-28  6194964     1393.0    6485  31665571.0    6868.0  34760
# 2023-05-27  6191196     4078.0    6485  31647238.0   17796.0  34784
# ...             ...        ...     ...         ...       ...    ...
# 2020-02-09       10        0.0       0        27.0       0.0      0
# 2020-02-08       10        0.0       0        24.0       0.0      0
# 2020-02-07       10        0.0       0        24.0       0.0      0
# 2020-02-06       11        0.0       0        24.0       0.0      0
# 2020-02-05        8        0.0       0        18.0       0.0      0
#
# [1212 rows x 6 columns]

# %%
# 1주일간의 데이터 추출
df1 = df.iloc[0:7]
df2 = df1.sort_values('서울시 기준일', ascending=True)
df2
# Out:
#              서울 확진자  서울시 일일 확진  서울시 사망       전국 확진  전국 일일 확진  전국 사망
# 서울시 기준일
# 2023-05-25  6183062     4435.0    6481  31611509.0   19080.0  34736
# 2023-05-26  6187279     4217.0    6483  31629442.0   17933.0  34781
# 2023-05-27  6191196     4078.0    6485  31647238.0   17796.0  34784
# 2023-05-28  6194964     1393.0    6485  31665571.0    6868.0  34760
# 2023-05-29  6194964     1393.0    6485  31665571.0    6868.0  34760
# 2023-05-30  6198290     3326.0    6486  31679100.0   13529.0  34767
# 2023-05-31  6204277     5987.0    6492  31703511.0   24411.0  34784

# %%
# 2행 1열의 서프플롯 만들기
fig, ax1= plt.subplots(1,1)

# 각각의 그래프에 대한 twinx 구현


# ax1에 그래프 그리기
sb.barplot(data = df2, x = df2.index, y = '서울 확진자', ax = ax1)

plt.ylim(6000000, 6300000)






plt.show()
plt.close()
