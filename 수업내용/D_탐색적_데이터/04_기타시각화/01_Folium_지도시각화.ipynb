# %% [markdown]
# # 지도 시각화
#
# ## # 01. 필요한 패키지 참조
#
#   * folium 패키지가 설치 되어야  한다.

# %%
import folium
from pandas import read_excel
from os import path, mkdir

# %% [markdown]
# ## # 02. 지도 표현하기
#
#   #### 1) 지도 객체 생성
#
#         - 지도의 중심이 되는 위도와 경도를 설정

# %%
# zoom-start: 배율 1~22
map_osm = folium.Map(location = [37.5004444, 127.0313861], zoom_start =  17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_225afd1ba13ca3251ecf6c4218327979 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_225afd1ba13ca3251ecf6c4218327979&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_225afd1ba13ca3251ecf6c4218327979 = L.map(
#                 &quot;map_225afd1ba13ca3251ecf6c4218327979&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e49b98179c25bb4876a0ed24e844245 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_225afd1ba13ca3251ecf6c4218327979);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
#   #### 2) 지도객체에 마커 추가
#
#     - 일반 마커
#
#       * 아이콘 색생값 종류
#
#         --'lightgreen', 'darkgreen', 'darkblue', 'cadetblue', 'orange', 'lightred', 'darkred', 'green', 'blue', 'black', 'lightblue', 'white', 'lightgray', 'red', 'pink', 'beige', 'gray', 'purple', 'darkpurple'

# %%
# 새로운 지도 객체 생성
map_osm1 = folium.Map(location = [37.5004444, 127.0313861], zoom_start=17)

# 마커 객체 생성
# Marker 가 표시될 위치 [위도, 경도]. 클리시 표시될 메시지. 아이콘 색상
marker1 = folium.Marker([37.5004444, 127.0313861], 
                        popup='메가스터디IT아카데미 강남', 
                        icon=folium.Icon(color='darkred'))

marker1.add_to(map_osm1) # 마커 객체를 지도에 추가함
map_osm1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1057a1b6abde8a4ee67a912b426ee4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1057a1b6abde8a4ee67a912b426ee4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1057a1b6abde8a4ee67a912b426ee4d = L.map(
#                 &quot;map_c1057a1b6abde8a4ee67a912b426ee4d&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1998ccb3001020c877272876375c140 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c1057a1b6abde8a4ee67a912b426ee4d);
#
#
#             var marker_4160d1097e35ddb4c8e51c7b7d27de6f = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_c1057a1b6abde8a4ee67a912b426ee4d);
#
#
#             var icon_8d816de7150e882b36e6866a941d4812 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4160d1097e35ddb4c8e51c7b7d27de6f.setIcon(icon_8d816de7150e882b36e6866a941d4812);
#
#
#         var popup_7bd44e0bf23681688beb9e1f40c66ccd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4c0088a139a76139c99ac3d1de7b0ef = $(`&lt;div id=&quot;html_f4c0088a139a76139c99ac3d1de7b0ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;메가스터디IT아카데미 강남&lt;/div&gt;`)[0];
#                 popup_7bd44e0bf23681688beb9e1f40c66ccd.setContent(html_f4c0088a139a76139c99ac3d1de7b0ef);
#
#
#
#         marker_4160d1097e35ddb4c8e51c7b7d27de6f.bindPopup(popup_7bd44e0bf23681688beb9e1f40c66ccd)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 사용자 지정 아이콘, HTML 팝업

# %%
# 새로운 지도 객체 생성
map_osm2 = folium.Map(location = [37.5004444, 127.0313861], zoom_start=17)

# HTML을 사용한 팝업
popup_html = folium.Popup("<div style='white-space: nowrap'><h3>메가스터디IT아카데미 강남</h3><img src='https://img.megastudyacademy.co.kr/campus/iws_html_img/it_brand/sec08_img01.png' width='100%'><br/><p>tel: <a href='tel:07043380972'>070-4338-0972</a></p><p>서울특별시 강남구 강남대로94길 삼경빌딩 2층</p></div>", parse_html=False)

# 사용자 지정 아이콘 이미지 사용
# --> 온라인 상의 URL, 내 컴퓨터 상의 상대,절대경로 모두 가능함
icon_img = folium.features.CustomIcon('https://data.hossam.kr/D04/ho.png', icon_size=(50, 50))

# 마커 객체 생성
marker2 = folium.Marker([37.5004444, 127.0313861], 
                        popup=popup_html,
                        icon=icon_img)

marker2.add_to(map_osm2) # 마커 객체를 지도에 추가함

# 웹 페이지 파일이 저장될 폴더 생성
if not path.exists('output'):
    mkdir('output')

map_osm2.save('output/map_osm2.html') #파일이 저장될 위치

map_osm2                 # 지도 표시하기
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fbd0e512667793e60f8d28d9cf1a53a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fbd0e512667793e60f8d28d9cf1a53a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fbd0e512667793e60f8d28d9cf1a53a = L.map(
#                 &quot;map_4fbd0e512667793e60f8d28d9cf1a53a&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53f8f314af9fa76f7687a5d0bbccf5e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4fbd0e512667793e60f8d28d9cf1a53a);
#
#
#             var marker_325fe1e6dec73d912dce90fa4f5ea44b = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_4fbd0e512667793e60f8d28d9cf1a53a);
#
#
#         var custom_icon_edd12936953432bb4ed5ddeab7c95838 = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;https://data.hossam.kr/D04/ho.png&quot;});
#         marker_325fe1e6dec73d912dce90fa4f5ea44b.setIcon(custom_icon_edd12936953432bb4ed5ddeab7c95838);
#
#
#         var popup_bb96d57463f25e4b98f99d7db12e07d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c35d2e1b3e2ad87439a82cf8fb88cde = $(`&lt;div id=&quot;html_2c35d2e1b3e2ad87439a82cf8fb88cde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;white-space: nowrap&#x27;&gt;&lt;h3&gt;메가스터디IT아카데미 강남&lt;/h3&gt;&lt;img src=&#x27;https://img.megastudyacademy.co.kr/campus/iws_html_img/it_brand/sec08_img01.png&#x27; width=&#x27;100%&#x27;&gt;&lt;br/&gt;&lt;p&gt;tel: &lt;a href=&#x27;tel:07043380972&#x27;&gt;070-4338-0972&lt;/a&gt;&lt;/p&gt;&lt;p&gt;서울특별시 강남구 강남대로94길 삼경빌딩 2층&lt;/p&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_bb96d57463f25e4b98f99d7db12e07d3.setContent(html_2c35d2e1b3e2ad87439a82cf8fb88cde);
#
#
#
#         marker_325fe1e6dec73d912dce90fa4f5ea44b.bindPopup(popup_bb96d57463f25e4b98f99d7db12e07d3)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 원형 마커(범위지정)

# %%
# 새로운 지도 객체 생성
map_osm3 = folium.Map(location=[37.5004444, 127.0313861], zoom_start=17)

# 마커 객체 생성
marker1 = folium.Marker([37.5004444, 127.0313861],  
                        icon=folium.Icon(color='orange'))

# 원형마커
marker2 = folium.CircleMarker([37.5004444, 127.0313861], 
                              radius=100,                 # 범위
                              color='#3186cc',            # 선 색상
                              fill_color='#3186cc')       # 면 색상

# 원형 마커 위에 아이콘 마커 올리기
marker2.add_to(map_osm3)
marker1.add_to(map_osm3)

# 마커 객체 생성
marker3 = folium.Marker([37.5005454, 127.0314871],  
                        icon=folium.Icon(color='red'))
map_osm3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_870d866fe3b136d0e568e62f40d020b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_870d866fe3b136d0e568e62f40d020b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_870d866fe3b136d0e568e62f40d020b3 = L.map(
#                 &quot;map_870d866fe3b136d0e568e62f40d020b3&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e298b6da5b83e99a3308a40661073609 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_870d866fe3b136d0e568e62f40d020b3);
#
#
#             var circle_marker_e14b25abb1c20ee5bcbfe74a4d5691a3 = L.circleMarker(
#                 [37.5004444, 127.0313861],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_870d866fe3b136d0e568e62f40d020b3);
#
#
#             var marker_d7567b9f418fa5bd70b62d75a7e355d3 = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_870d866fe3b136d0e568e62f40d020b3);
#
#
#             var icon_8860e9cdec41fc12ae81ae2dfb5e09ab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7567b9f418fa5bd70b62d75a7e355d3.setIcon(icon_8860e9cdec41fc12ae81ae2dfb5e09ab);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
#   #### 3) 다른 형태의 지도
#
# ####  평면도

# %%
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.5005454, 127.0314871], zoom_start=17, 
                      tiles='Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62cde8391a6f66bd44c7a76c44a0f0f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62cde8391a6f66bd44c7a76c44a0f0f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62cde8391a6f66bd44c7a76c44a0f0f9 = L.map(
#                 &quot;map_62cde8391a6f66bd44c7a76c44a0f0f9&quot;,
#                 {
#                     center: [37.5005454, 127.0314871],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c661bd57a8072deb273eb81a53c0d097 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_62cde8391a6f66bd44c7a76c44a0f0f9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 지형도

# %%
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.5005454, 127.0314871], zoom_start=11, 
                     tiles='Stamen Terrain')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74e6fb06d742d808d261d08a7fc5a774 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74e6fb06d742d808d261d08a7fc5a774&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74e6fb06d742d808d261d08a7fc5a774 = L.map(
#                 &quot;map_74e6fb06d742d808d261d08a7fc5a774&quot;,
#                 {
#                     center: [37.5005454, 127.0314871],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07289c4f7644b07e61342cc24296bddb = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74e6fb06d742d808d261d08a7fc5a774);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## # 03. (예제) 서울의 고등학교 분포 확인하기
#
#   #### 1) 데이터 준비하기
#
#     - 전국 초,중,고 학교 위치 엑세 파일을 원격으로 내려받아 데이터프레임으로 변환(다소 시간이 소요된다.)
#
#   ##### 데이터 출처: 공공데이터 포털

# %%
xlsx = read_excel("https://data.hossam.kr/D04/school.xlsx")
xlsx
# Out:
#              학교ID          학교명 학교급구분        설립일자 설립형태 본교분교구분 운영상태  \
# 0      B000004204       한울초등학교  초등학교  2008-09-01   공립     본교   운영
# 1      B000011476  수원농생명과학고등학교  고등학교  1936-07-01   공립     본교   운영
# 2      B000009647        녹양중학교   중학교  2008-03-01   공립     본교   운영
# 3      B000005955       초락초등학교  초등학교  1959-04-02   공립     본교   운영
# 4      B000005385       상봉초등학교  초등학교  1946-09-01   공립     본교   운영
# ...           ...          ...   ...         ...  ...    ...  ...
# 11983  B000003371     대전옥계초등학교  초등학교  1982-12-09   공립     본교   운영
# 11984  B000003345       성덕초등학교  초등학교  2011-03-11   공립     본교   운영
# 11985  B000005441       이월초등학교  초등학교  1920-04-01   공립     본교   운영
# 11986  B000009875        해안중학교   중학교  1979-03-08   공립     본교   운영
# 11987  B000011237        초계중학교   중학교  1952-06-01   공립     본교   운영
#
#                           소재지지번주소                                    소재지도로명주소  \
# 0             경기도 화성시 향남읍 행정리 442        경기도 화성시 향남읍 행정중앙1로 25 . 한울초등학교 (향남읍)
# 1             경기도 수원시 장안구 영화동 109         경기도 수원시 장안구 광교산로 13 (영화동.농생명과학고등학교)
# 2              경기도 의정부시 녹양동 191-5              경기도 의정부시 체육로 187 . 녹양중학교 (녹양동)
# 3         충청남도 당진시 석문면 초락도리 210-3                  충청남도 당진시 석문면 샛터말길 35 (석문면)
# 4      충청북도 청주시 흥덕구 오송읍 상봉리 242-1       충청북도 청주시 흥덕구 오송읍 상봉길 9 . 상봉초등학교 (오송읍)
# ...                           ...                                         ...
# 11983             대전광역시 중구 옥계동 65             대전광역시 중구 모암로 35 (옥계동. 대전옥계초등학교)
# 11984          광주광역시 광산구 장덕동 1042            광주광역시 광산구 풍영로 313 . 성덕초등학교 (장덕동)
# 11985        충청북도 진천군 이월면 송림리 667         충청북도 진천군 이월면 송림6길 26 . 이월초등학교 (이월면)
# 11986          강원도 양구군 해안면 현리 143                 강원도 양구군 해안면 펀치볼로 1279 (해안면)
# 11987         경상남도 합천군 초계면 아막리 99  경상남도 합천군 초계면 초계중앙로 83 . 초계중학교 (초계면. 초계중학교)
#
#        시도교육청코드    시도교육청명  교육지원청코드        교육지원청명        생성일자        변경일자  \
# 0      7530000    경기도교육청  7679000  경기도화성오산교육지원청  2013-11-29  2022-10-06
# 1      7530000    경기도교육청  7541000    경기도수원교육지원청  2013-11-29  2022-10-06
# 2      7530000    경기도교육청  7561000   경기도의정부교육지원청  2013-11-29  2022-10-06
# 3      8140000   충청남도교육청  8291000   충청남도당진교육지원청  2013-11-29  2022-10-06
# 4      8000000   충청북도교육청  8011000   충청북도청주교육지원청  2013-11-29  2022-10-06
# ...        ...       ...      ...           ...         ...         ...
# 11983  7430000  대전광역시교육청  7441000  대전광역시동부교육지원청  2013-11-29  2022-10-06
# 11984  7380000  광주광역시교육청  7401000  광주광역시서부교육지원청  2013-11-29  2022-10-06
# 11985  8000000   충청북도교육청  8081000   충청북도진천교육지원청  2013-11-29  2022-10-06
# 11986  7800000    강원도교육청  7951000    강원도양구교육지원청  2013-11-29  2022-10-06
# 11987  9010000   경상남도교육청  9221000   경상남도합천교육지원청  2013-11-29  2022-10-06
#
#               위도          경도     데이터기준일자   제공기관코드            제공기관명
# 0      37.126961  126.917854  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 1      37.295154  127.019450  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 2      37.761864  127.028084  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 3      36.993080  126.510472  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 4      36.638251  127.286142  2023-03-22  C738100  청주대학교 지방교육재정연구원
# ...          ...         ...         ...      ...              ...
# 11983  36.301199  127.449039  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11984  35.199148  126.814301  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11985  36.931076  127.431922  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11986  38.283771  128.135686  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11987  35.560066  128.270502  2023-03-22  C738100  청주대학교 지방교육재정연구원
#
# [11988 rows x 20 columns]

# %% [markdown]
#   #### 2) 데이터 전처리
#
#     - 사용할 필드만 추출

# %%
df = xlsx.filter(['학교명', '학교급구분', '소재지도로명주소', '위도', '경도'])
df
# Out:
#                학교명 학교급구분                                    소재지도로명주소  \
# 0           한울초등학교  초등학교        경기도 화성시 향남읍 행정중앙1로 25 . 한울초등학교 (향남읍)
# 1      수원농생명과학고등학교  고등학교         경기도 수원시 장안구 광교산로 13 (영화동.농생명과학고등학교)
# 2            녹양중학교   중학교              경기도 의정부시 체육로 187 . 녹양중학교 (녹양동)
# 3           초락초등학교  초등학교                  충청남도 당진시 석문면 샛터말길 35 (석문면)
# 4           상봉초등학교  초등학교       충청북도 청주시 흥덕구 오송읍 상봉길 9 . 상봉초등학교 (오송읍)
# ...            ...   ...                                         ...
# 11983     대전옥계초등학교  초등학교             대전광역시 중구 모암로 35 (옥계동. 대전옥계초등학교)
# 11984       성덕초등학교  초등학교            광주광역시 광산구 풍영로 313 . 성덕초등학교 (장덕동)
# 11985       이월초등학교  초등학교         충청북도 진천군 이월면 송림6길 26 . 이월초등학교 (이월면)
# 11986        해안중학교   중학교                 강원도 양구군 해안면 펀치볼로 1279 (해안면)
# 11987        초계중학교   중학교  경상남도 합천군 초계면 초계중앙로 83 . 초계중학교 (초계면. 초계중학교)
#
#               위도          경도
# 0      37.126961  126.917854
# 1      37.295154  127.019450
# 2      37.761864  127.028084
# 3      36.993080  126.510472
# 4      36.638251  127.286142
# ...          ...         ...
# 11983  36.301199  127.449039
# 11984  35.199148  126.814301
# 11985  36.931076  127.431922
# 11986  38.283771  128.135686
# 11987  35.560066  128.270502
#
# [11988 rows x 5 columns]

# %% [markdown]
# #### 서울시의 고등학교만 추출
#
#   - 학교급구분 필드 값이 고등학교이고, 소재지도로명주소에 '서울' 이라는 단어가 포함된 경우
#
#   # LIKE 연산 -> 원하는 단어가 포함되어 있는 데이터 출력
#
#   컬럼이름.str.contains('검색어')

# %%
df2 = df.query("학교급구분 == '고등학교' and 소재지도로명주소.str.contains('서울')")
df2
# Out:
#               학교명 학교급구분                                        소재지도로명주소  \
# 6          경기고등학교  고등학교               서울특별시 강남구 영동대로 643 . 경기고등학교 (삼성동)
# 89       대일관광고등학교  고등학교  서울특별시 양천구 신정이펜1로 11 . 대일관광고등학교 (신정동. 대일관광고등학교)
# 97         한광고등학교  고등학교                      서울특별시 강서구 등촌로13길 110 (화곡동)
# 98      상일미디어고등학교  고등학교         서울특별시 강동구 천호대로219길 61 . 상일미디어고등학교 (상일동)
# 118    선정국제관광고등학교  고등학교         서울특별시 은평구 서오릉로20길 19 . 선정국제관광고등학교 (갈현동)
# ...           ...   ...                                             ...
# 11429      성수고등학교  고등학교              서울특별시 성동구 서울숲길 18 . 성수고등학교 (성수동1가)
# 11451    대진여자고등학교  고등학교              서울특별시 노원구 공릉로 438 . 대진여자고등학교 (중계동)
# 11564      도선고등학교  고등학교                       서울특별시 성동구 마장로 156 (하왕십리동)
# 11600      금호고등학교  고등학교               서울특별시 성동구 금호로 118 (금호동1가. 금호고등학교)
# 11929  서울인공지능고등학교  고등학교                          서울특별시 송파구 양산로 21 (거여동)
#
#               위도          경도
# 6      37.517565  127.056076
# 89     37.511414  126.834907
# 97     37.538844  126.857922
# 98     37.549470  127.170767
# 118    37.618705  126.909032
# ...          ...         ...
# 11429  37.547342  127.038253
# 11451  37.646174  127.067197
# 11564  37.566844  127.026996
# 11600  37.553621  127.023434
# 11929  37.491753  127.142331
#
# [320 rows x 5 columns]

# %% [markdown]
# #### 3) 데이터 시각화

# %%
# zoom_start: 배율 1~22 (여기서는 출력 안함)
map_osm = folium.Map(location=[37.566651, 126.978428], zoom_start=12)

html = "<font color = 'green' style = 'white-space : nowrap'><b>%s</b></font>"

# 데이터프레임의 행 수만큼 반복하면서 마커 생성
for i in df2.index:
    # 행 우선 접근 방식으로 값 추출하기
    name = df2.loc[i, '학교명']
    lat = df2.loc[i, '위도']
    lng = df2.loc[i, '경도']

    # 추출한 정보를 지도에 표시
    popup_html = folium.Popup(html % name, parse_html = False)
    marker = folium.Marker([lat, lng], popup = popup_html)
    marker.add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f75c9911795bc74763139f73ba510dbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f75c9911795bc74763139f73ba510dbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f75c9911795bc74763139f73ba510dbc = L.map(
#                 &quot;map_f75c9911795bc74763139f73ba510dbc&quot;,
#                 {
#                     center: [37.566651, 126.978428],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_816a5c6ab6a81064a88b467a12d5d6fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f75c9911795bc74763139f73ba510dbc);
#
#
#             var marker_aa97c9b905a24a90f192b6c8f69d0ac3 = L.marker(
#                 [37.5175645399, 127.0560755056],
#                 {}
#             ).addTo(map_f75c9911795bc74763139f73ba510dbc);
#
#
#         var popup_b16a8ab427b90353ec63f8850ceffa1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b26b121eb56aec53c802ddd3d4bc232 = $(`&lt;div id=&quot;html_7b26b121eb56aec53c802ddd3d4bc232&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color = &#x27;green&#x27; style = &#x27;white-space : nowrap&#x27;&gt;&lt;b&gt;경기고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_b16a8ab427b90353ec63f8850ceffa1d.setContent(html_7b26b121eb56aec53c802ddd3d4bc232);
#
#
#
#         marker_aa97c9b905a24a90f192b6c8f69d0ac3.bindPopup(popup_b16a8ab427b90353ec63f8850ceffa1d)
#         ;
#
#
#
#
#             var marker_4b1bb18e315d722cb139f5e133bbf7ce = L.marker(
#                 [37.5114137684, 126.8349067147],
#                 {}
#             ).addTo(map_f75c9911795bc74763139f73ba510dbc);
#
#
#         var popup_4e3e3ff4794a79cd41f17ffbe271b223 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41bf81492df058398ad52f6fb3ec1f4d = $(`&lt;div id=&quot;html_41bf81492df058398ad52f6fb3ec1f4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color = &#x27;green&#x27; style = &#x27;white-space : nowrap&#x27;&gt;&lt;b&gt;대일관광고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_4e3e3ff4794a79cd41f17ffbe271b223.setContent(html_41bf81492df058398ad52f6fb3ec1f4d);
#
#
#
#         marker_4b1bb18e315d722cb139f5e133bbf7ce.bindPopup(popup_4e3e3ff4794a79cd41f17ffbe271b223)
#         ;
#
#
#
#
#             var marker_9e11b184a230faeda6eabfc3a60a025d = L.marker(
#                 [37.5388437129, 126.857922],
#                 {}
#             ).addTo(map_f75c9911795bc74763139f73ba510dbc);
#
#
#         var popup_2ad0bff26a7a2996f5717bb8882aed0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bfe44b03eddd51237fc3805878b530a = $(`&lt;div id=&quot;html_9bfe44b03eddd51237fc3805878b530a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color = &#x27;green&#x27; style = &#x27;white-space : nowrap&#x27;&gt;&lt;b&gt;한광고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_2ad0bff26a7a2996f5717bb8882aed0a.setContent(html_9bfe44b03eddd51237fc3805878b530a);
#
#
#
#         marker_9e11b184a230faeda6eabfc3a60a025d.bindPopup(popup_2ad0bff26a7a2996f5717bb8882aed0a)
#         ;
#
#
#
#
#             var marker_4f0b0c7caf1ce8dd6aee71638fb35308 = L.marker(
#                 [37.5494699071, 127.1707668179],
#                 {}
#             ).addTo(map_f75c9911795bc74763139f73ba510dbc);
#
#
#         var popup_6db776e6a7d9b8ecf289a9d4ac6d09a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d16f611f3c41a4f41f94624ef7dce15c = $(`&lt;div id=&quot;html_d16f611f3c41a4f41f94624ef7dce15c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color = &#x27;green&#x27; style = &#x27;white-space : nowrap&#x27;&gt;&lt;b&gt;상일미디어고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_6db776e6a7d9b8ecf289a9d4ac6d09a2.setContent(html_d16f611f3c41a4f41f94624ef7dce15c);
#
#
#
#         marker_4f0b0c7caf1ce8dd6aee71638fb35308.bindPopup(popup_6db776e6a7d9b8ecf289a9d4ac6d09a2)
#         ;
#
#
#
#
#             var marker_fca6256e3f69f6717ba1e0779e9d5d3a = L.marker(
#                 [37.6187045126, 126.9090316117],
#                 {}
#             ).addTo(map_f75c9911795bc74763139f73ba510dbc);
#
#
#         var popup_b4591d80896a2ae9309d2abe32e6b8f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ffc9347284c68c6ceaab877122403d7 = $(`&lt;div id=&quot;html_3ffc9347284c68c6ceaab877122403d7&quot; st
